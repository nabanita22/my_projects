# %%
MENU = {
    "espresso": {
        "ingredients": {
            "water": 50,
            "coffee": 18,
        },
        "cost": 15,
    },
    "latte": {
        "ingredients": {
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 25,
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 30,
    }
}

resources = {
    "water": 300,
    "milk": 200,
    "coffee": 100,
}

money=0
0
def show_report(ask):
    for i,j in resources.items():
        print(f"{i} :{j}ml")
    print(f" money received : {money}")
    
    

on=1
while on==1:
    
    print("we welcome you to nab's online coffee shop")
    ask=input("What would you like? (espresso(price 15)/latte(price 25)/cappuccino(price 30))\nfor viewing report type 'report':\n").lower()
    total=0     
    if ask=="report":
        show_report(ask)
        ask2=input("to close the counter type 1 to continue type 2: ")
    if ask in ["espresso","latte","cappuccino"]:
        print("plz insert coins.")
        ask_1=int(input("how many ones?"))
        ask_2=int(input("how many twoes?"))
        ask_5=int(input("how many fives?"))
        ask_10=int(input("how many tens?"))

        total=ask_1*1+ask_2*2+ask_5*5+ask_10*10
        print(total)

        if MENU[ask]["cost"]<=total:

            for i in MENU[ask]["ingredients"]:
                if MENU[ask]["ingredients"][i]<=resources[i]:
                    resources[i]=resources[i]-MENU[ask]["ingredients"][i]
            balance=total-MENU[ask]["cost"]
            print(f"take your balance {balance}")
            print(f"enjoy here is your {ask}")
            money=money+MENU[ask]["cost"]

        if MENU[ask]["cost"]>total or MENU[ask]["ingredients"][i]>resources[i]  :
            print(f"sorry we are not able to give you {ask}")
            print(f'refunded {total}')
        ask2=input("to close the counter type 1 to continue type 2: ")
    if ask2=="1":
        on=0
# Out:
# we welcome you to nab's online coffee shop
# What would you like? (espresso(price 15)/latte(price 25)/cappuccino(price 30))
# for viewing report type 'report':
# report
# water :300ml
# milk :200ml
# coffee :100ml
#  money received : 0
# to close the counter type 1 to continue type 2: 2
# we welcome you to nab's online coffee shop
# What would you like? (espresso(price 15)/latte(price 25)/cappuccino(price 30))
# for viewing report type 'report':
# espresso
# plz insert coins.
# how many ones?8
# how many twoes?9
# how many fives?0
# how many tens?0
# 26
# take your balance 11
# enjoy here is your espresso
# to close the counter type 1 to continue type 2: report
# we welcome you to nab's online coffee shop
# What would you like? (espresso(price 15)/latte(price 25)/cappuccino(price 30))
# for viewing report type 'report':
# 2
# we welcome you to nab's online coffee shop
# What would you like? (espresso(price 15)/latte(price 25)/cappuccino(price 30))
# for viewing report type 'report':
# ...
