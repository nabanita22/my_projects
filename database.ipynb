# %%
def student_input1(a,b,c,d):
    student_input={}
    
    student_input["name"]=a
    
    
    
    
    
    student_input["ph_num"]=b
    
    
    
    
    student_input["email_id"]=c
    student_input["age"]=d
    #return(student_input)

    database=[]
    database.append(student_input)
    return(database)




    
raw_list=[]    
raw={}    
final_database=[]
total_student=0
a=1
#student_input={}    
i=999999999

while i>0:
    
    
    iin=9
    while iin>0:
        number=input(""""type 1 to update the existing database\ntype 2 to only see the existing database\ntype 3 to add new entry\ntype 4 to close the database\ntype 5 to delete the existing database: \n""")
       
        
        
    
        if number=="3":
            piu4=9
            while piu4>0:
                
                name_input1=input("tell your first name\n")
                name_input2=input("tell your last name\n")
                if name_input1==" "or name_input2==" ":
                    print("mandatory field,cant remain blank")
                    piu4+=1
                else:
                    piu4=0

            total_name=name_input1.upper()+" "+name_input2.upper()
            raw["name"]=total_name

            ph_num=input("give a valid ph num\n")

            p=99999999
            while p>0:
                ph_num_check=ph_num[0]
                ph_num_check=int(ph_num_check)


                for ii in final_database:
                    for jj in ii:
                        for kk in jj.values():
                            if ph_num==kk:
                                print("your ph num should not be an used one\n")
                                ph_num=input("give a not used ph number\n")
                                p=p-1




                if len(ph_num)!=10:
                    print("ph num must contain 10 digits\n")
                    ph_num=input("give a valid ph num\n")
                    p=p-1


                #elif  total_student>0 and ph_num in raw["ph_num"]:
                    #print("your ph num should not be an used one\n")
                    #ph_num=input("give a not used ph number\n")
                   # p=p-1

                elif ph_num_check in range (0,5):
                    print("invalid ph_number")
                    ph_num=input("your ph number should start from 5 to 9")
                    p=p-1


                else:
                    raw["ph_num"]=ph_num
                    p=0









            print("email-id format is lastname.firstname(student_id)22-24@bibs.co.in")
            print(f"your default id value is {a}")
            email_id=input("give a valid email id\n")
            
            email_format=name_input2+"."+name_input1+str(a)+"22-24@bibs.co.in"
            r=9999999999
            while r>0:
                if email_id !=email_format :
                    print("your mail id should be 'lastname.firstname(value of a)22-24@bibs.co.in' format")
                    email_id=input("give a valid email id\n")
                    r=r+1

                else:

                    raw["email_id"]=email_id
                    r=0

            q=99999999
            while q>0:
                age=int(input("what is your age?"))
                if age>18 and age<40:
                    x=student_input1(total_name,ph_num,email_id,age)
                    raw["age"]=age 
                    q=0 
                else:

                    print("you are not eligible\n")
                    raw["age"]=age
                    q=0
                    #ask=input("is there anyone left?")




            sk=999
            while sk>0:
                print(raw)

                ask2=input("do you want to retain this form?\n".lower())
                if ask2=="yes":
                    a=a+1
                    sk=0
                    final_database.append(x)
                    raw_list.append(raw)
                elif ask2=="no":
                    sk=0

                else:
                    print("type only 'yes' or 'no'")
                    sk=sk-1

            sk2=9999
            while sk2>0:

                ask=input("is there anyone left?\n".lower())
                if ask=="yes":
                    total_student+=1
                    sk2=0
                    i=i+1
                    iin=iin+1

                elif ask=="no":
                    
                    i=0
                    sk2=0
                    total_student+=1
                    iin=iin+1
                    print(f"total {a-1} students have submitted the form.")
                    print(final_database)
                    #a=a+1

                else:
                    print("type only 'yes' or 'no'")
                    sk2+=1


#print(f"total {a} students have submitted the form.")
#print(final_database)
        
        if number=="1":
            llp=[]
            if total_student==0:
                print("your data base is empty")
                iin=iin+1   
            elif total_student>0:
                
                for ixx in final_database:
                    for j in ixx:
                        for m in j:
                            if m=="ph_num":
                                llp.append(j[m])
            
                piu=9
                while piu>0:
                    
                    ph_num=input("type the previous ph number.")
                    #up_ask=input("what do you want to update?total_name/ph_num/email_id/age")
                    #ask_value=input("what will be the value?")
                    
                    #for ix in llp:
                    if ph_num in llp:
                        
                        for c in final_database:
                            for d in c:
                                for e in d:
                                    if d[e]==ph_num:
                                        print(d)
                                        aaa=final_database.index(c)
                                        a11=d["email_id"][-17]
                                        piu=0
            
                        
                        #print(j)
                        
                    
                    elif ph_num not in llp:
                     
                        piu=piu+1
                        print("ph_number is not in database")   

                #raw_list=[]    
                #raw={}    
                #final_database=[]
                #total_student=0
                a=a
                #student_input={}    
                #i=999999999

                #while i>0:






                name_input1=input("tell your first name\n")
                name_input2=input("tell your last name\n")

                total_name=name_input1.upper()+" "+name_input2.upper()
                raw["name"]=total_name

                ask10=input("do you want to retain the previous number?")
                if ask10=="yes":
                    ph_num=ph_num
                    raw["ph_num"]=ph_num
                elif ask10=="no":
                    
                    ph_num=input("give a valid and non used ph num\n")

                    p=99999999
                    while p>0:
                        ph_num_check=ph_num[0]
                        ph_num_check=int(ph_num_check)


                        for ii in final_database:
                            for jj in ii:
                                for kk in jj.values():
                                    if ph_num==kk:
                                        print("your ph num should not be an used one\n")
                                        ph_num=input("give a not used ph number\n")
                                        p=p-1




                        if len(ph_num)!=10:
                            print("ph num must contain 10 digits\n")
                            ph_num=input("give a valid ph num\n")
                            p=p-1


                        #elif  total_student>0 and ph_num in raw["ph_num"]:
                            #print("your ph num should not be an used one\n")
                            #ph_num=input("give a not used ph number\n")
                           # p=p-1

                        elif ph_num_check in range (0,5):
                            print("invalid ph_number")
                            ph_num=input("your ph number should start from 5 to 9")
                            p=p-1


                        else:
                            raw["ph_num"]=ph_num
                            p=0

                    

                print("email-id format is lastname.firstname(student_id)22-24@bibs.co.in")
                print(f"your default id value is {a11}")

                email_id=input("give a valid email id\n")
                email_format=name_input2+"."+name_input1+str(a11)+"22-24@bibs.co.in"
                r=9999999999
                while r>0:
                    if email_id !=email_format :
                        print("your mail id should be 'lastname.firstname(student_id)22-24@bibs.co.in' format")
                        email_id=input("give a valid email id\n")
                        r=r+1

                    else:

                        raw["email_id"]=email_id
                        r=0

                q=99999999
                while q>0:
                    age=int(input("what is your age?"))
                    if age>18 and age<40:
                        x=student_input1(total_name,ph_num,email_id,age)
                        raw["age"]=age 
                        q=0 
                    else:

                        print("you are not eligible\n")
                        raw["age"]=age
                        q=0
                        #ask=input("is there anyone left?")




                sk=999 
                while sk>0:
                    print(raw)

                    ask2=input("do you want to retain this form?'yes' or 'no'\n".lower())
                    if ask2=="yes":

                        sk=0
                        final_database[aaa]=x
                        raw_list.append(raw)
                        print(f"total {a-1} students have submitted the form.")
                        print(final_database)
                        a=a
                        iin=iin+1

                    elif ask2=="no":
                        sk=0
                        iin=iin+1

                    else:
                        print("type only 'yes' or 'no'")
                        sk=sk-1
        if number=="2":
            llp=[]
                
                
            if total_student==0:
                print("your databse is empty")
            elif total_student>0:
                for i in final_database:
                    for j in i:
                        for m in j:
                            if m=="ph_num":
                                llp.append(j[m])
            piu5=9
            while piu5>0:
                
                ph_num=input("type the enlisted ph number.")


                if ph_num in llp:
                    for c in final_database:
                            for d in c:
                                for e in d:
                                    if d[e]==ph_num:
                                        print(d)

                    #print(j)
                    piu5=0

                elif ph_num not in llp:
                    print("ph_number not in database")
                    piu5+=1

            ask9=input("do you want to see the whole database?type only'yes' or 'no'")
            if ask9=="yes":
                print(final_database)
                print(f"total{a-1} students have submitted the form")
                iin=iin+1
            elif ask9=="no":
                iin=iin+1
            else:
                print("type only 'yes' or 'no'.")

        if number=="4":
            iin=0
            i=0
            print(f"total {a-1} students have submitted the form.")
            print(final_database)
            
        if number=="5":
            llpp=[]
            if total_student==0:
                print("your database is empty")
                
            elif total_student>0:
                for iix in final_database:
                    for j in iix:
                        for m in j:
                            if m=="ph_num":
                                llpp.append(j[m])
            piu7=9
            while piu7>0:
                
                ph_num=input("type the previous ph number.")
                if ph_num in llpp:
                    for c in final_database:
                            for d in c:
                                for e in d:
                                    if d[e]==ph_num:
                                        print(d)

                    piu7=0
                    #print(j)
                    ask11=input("do you want to delete this database?")
                    if ask11=="yes":

                        aaa=final_database.index(c)
                        final_database[aaa]=[]
                        a=a-1
                        print(f"now total number of students in database is {a-1}")
                        print(final_database)

                    elif ask11=="no":
                        print(f"now total number of students in database is {a-1}")
                        print(final_database)
                        iin=iin+1
                elif ph_num not in llpp:
                    print("ph_num is not in database")
                    piu7+=1
                
                            
                
        elif number!="1" and number!="2" and number!="3" and number!="4" and number!="5":
            print("invalid input")
            iin=iin+1
